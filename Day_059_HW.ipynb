# %% [markdown]
# <a href="https://colab.research.google.com/github/semishen/ML100Days/blob/master/Day_059_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 作業
# ### 用 digits (3個數字即可 , dataset.load_digits(n_class=3)) 資料嘗試跑 PCA

# %%
from sklearn import datasets

digits = datasets.load_digits(n_class=3)
X = digits.data
y = digits.target

# %% [markdown]
# 載入 相關套件 並 執行 PCA 實驗 ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
print(X.shape) #dim = 64
print(y.shape) #class = 3
# Out:
# (537, 64)
# (537,)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=3)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
result = pca.transform(X)
print(result.shape)
# Out:
# (537, 3)

# %%
fig = plt.figure(1, figsize=(5, 5))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
plt.cla()

ax.scatter(result[:, 0], result[:, 1], result[:, 2], c=y, cmap=plt.cm.nipy_spectral,
           edgecolor='k')
plt.show()
plt.close()
