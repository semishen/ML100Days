# %% [markdown]
# <a href="https://colab.research.google.com/github/semishen/ML100Days/blob/master/Day_008_HW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [作業目標]
# - 對資料做更多處理 : 顯示特定欄位的統計值與直方圖

# %% [markdown]
# # [作業重點]
# - 試著顯示特定欄位的基礎統計數值 (In[4], Out[4], Hint : describe())
# - 試著顯示特定欄位的直方圖 (In[5], Out[5], Hint : .hist())

# %%
# Import 需要的套件
import numpy as np
import pandas as pd

# %%
app_train = pd.read_csv('application_train.csv')
app_train.shape
# Out:
# (307511, 122)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 練習時間

# %% [markdown]
# 觀察有興趣的欄位的資料分佈，並嘗試找出有趣的訊息
# #### Eg
# - 計算任意欄位的平均數及標準差
# - 畫出任意欄位的[直方圖](https://zh.wikipedia.org/zh-tw/%E7%9B%B4%E6%96%B9%E5%9B%BE)
#
# ### Hints:
# - [Descriptive Statistics For pandas Dataframe](https://chrisalbon.com/python/data_wrangling/pandas_dataframe_descriptive_stats/)
# - [pandas 中的繪圖函數](https://amaozhao.gitbooks.io/pandas-notebook/content/pandas%E4%B8%AD%E7%9A%84%E7%BB%98%E5%9B%BE%E5%87%BD%E6%95%B0.html)

# %%
app_train.head()
# Out:
#    SK_ID_CURR  TARGET  ... AMT_REQ_CREDIT_BUREAU_QRT AMT_REQ_CREDIT_BUREAU_YEAR
# 0      100002       1  ...                       0.0                        1.0
# 1      100003       0  ...                       0.0                        0.0
# 2      100004       0  ...                       0.0                        0.0
# 3      100006       0  ...                       NaN                        NaN
# 4      100007       0  ...                       0.0                        0.0
#
# [5 rows x 122 columns]

# %%
app_train.dtypes.value_counts()
# Out:
# float64    65
# int64      41
# object     16
# dtype: int64

# %%
obj_df = app_train.select_dtypes(include='object')
obj_df.head()
# Out:
#   NAME_CONTRACT_TYPE CODE_GENDER  ... WALLSMATERIAL_MODE EMERGENCYSTATE_MODE
# 0         Cash loans           M  ...       Stone, brick                  No
# 1         Cash loans           F  ...              Block                  No
# 2    Revolving loans           M  ...                NaN                 NaN
# 3         Cash loans           F  ...                NaN                 NaN
# 4         Cash loans           M  ...                NaN                 NaN
#
# [5 rows x 16 columns]

# %%
int_df = app_train.select_dtypes(include='int')
int_df.head()
# Out:
#    SK_ID_CURR  TARGET  ...  FLAG_DOCUMENT_20  FLAG_DOCUMENT_21
# 0      100002       1  ...                 0                 0
# 1      100003       0  ...                 0                 0
# 2      100004       0  ...                 0                 0
# 3      100006       0  ...                 0                 0
# 4      100007       0  ...                 0                 0
#
# [5 rows x 41 columns]

# %%
float_df = app_train.select_dtypes(include='float')
float_df.head()
# Out:
#    AMT_INCOME_TOTAL  ...  AMT_REQ_CREDIT_BUREAU_YEAR
# 0          202500.0  ...                         1.0
# 1          270000.0  ...                         0.0
# 2           67500.0  ...                         0.0
# 3          135000.0  ...                         NaN
# 4          121500.0  ...                         0.0
#
# [5 rows x 65 columns]

# %%
print(float_df['AMT_INCOME_TOTAL'].describe())
float_df['AMT_INCOME_TOTAL'].plot()
# Out:
# count    3.075110e+05
# mean     1.687979e+05
# std      2.371231e+05
# min      2.565000e+04
# 25%      1.125000e+05
# 50%      1.471500e+05
# 75%      2.025000e+05
# max      1.170000e+08
# Name: AMT_INCOME_TOTAL, dtype: float64

# %%
print(float_df['AMT_CREDIT'].describe())
float_df['AMT_CREDIT'].plot()
# Out:
# count    3.075110e+05
# mean     5.990260e+05
# std      4.024908e+05
# min      4.500000e+04
# 25%      2.700000e+05
# 50%      5.135310e+05
# 75%      8.086500e+05
# max      4.050000e+06
# Name: AMT_CREDIT, dtype: float64

# %%
print(float_df['AMT_ANNUITY'].describe())
float_df['AMT_ANNUITY'].plot()
# Out:
# count    307499.000000
# mean      27108.573909
# std       14493.737315
# min        1615.500000
# 25%       16524.000000
# 50%       24903.000000
# 75%       34596.000000
# max      258025.500000
# Name: AMT_ANNUITY, dtype: float64

# %%
plt.figure(figsize=(12, 8))
chart = sns.boxplot(x="NAME_INCOME_TYPE", y="AMT_ANNUITY", data=app_train)
chart.set_xticklabels(chart.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'Working'),
#  Text(0, 0, 'State servant'),
#  Text(0, 0, 'Commercial associate'),
#  Text(0, 0, 'Pensioner'),
#  Text(0, 0, 'Unemployed'),
#  Text(0, 0, 'Student'),
#  Text(0, 0, 'Businessman'),
#  Text(0, 0, 'Maternity leave')]
